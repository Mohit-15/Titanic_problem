# %%
import pandas as pd
df=pd.read_csv("titanic.csv")
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
new_df=df.drop(['PassengerId','Name','Ticket','Embarked','Cabin'],axis='columns')
new_df.head()
# Out:
#    Survived  Pclass     Sex   Age  SibSp  Parch     Fare
# 0         0       3    male  22.0      1      0   7.2500
# 1         1       1  female  38.0      1      0  71.2833
# 2         1       3  female  26.0      0      0   7.9250
# 3         1       1  female  35.0      1      0  53.1000
# 4         0       3    male  35.0      0      0   8.0500

# %%
new=new_df.drop(['Survived'],axis='columns')
target=new_df['Survived']
new.head()
# Out:
#    Pclass     Sex   Age  SibSp  Parch     Fare
# 0       3    male  22.0      1      0   7.2500
# 1       1  female  38.0      1      0  71.2833
# 2       3  female  26.0      0      0   7.9250
# 3       1  female  35.0      1      0  53.1000
# 4       3    male  35.0      0      0   8.0500

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le_sex=LabelEncoder()

# %%
new['Sex_']=le_class.fit_transform(new["Sex"])

# %%
m=new.Age.fillna(0)
new.Age=m
new=new.drop(['Sex'],axis='columns')
new
# Out:
#      Pclass   Age  SibSp  Parch      Fare  Sex_
# 0         3  22.0      1      0    7.2500     1
# 1         1  38.0      1      0   71.2833     0
# 2         3  26.0      0      0    7.9250     0
# 3         1  35.0      1      0   53.1000     0
# 4         3  35.0      0      0    8.0500     1
# 5         3   0.0      0      0    8.4583     1
# 6         1  54.0      0      0   51.8625     1
# 7         3   2.0      3      1   21.0750     1
# 8         3  27.0      0      2   11.1333     0
# 9         2  14.0      1      0   30.0708     0
# 10        3   4.0      1      1   16.7000     0
# 11        1  58.0      0      0   26.5500     0
# 12        3  20.0      0      0    8.0500     1
# 13        3  39.0      1      5   31.2750     1
# 14        3  14.0      0      0    7.8542     0
# 15        2  55.0      0      0   16.0000     0
# 16        3   2.0      4      1   29.1250     1
# 17        2   0.0      0      0   13.0000     1
# 18        3  31.0      1      0   18.0000     0
# ...

# %%
from sklearn import tree
model= tree.DecisionTreeClassifier()

# %%
model.fit(new,target)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#                        max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort=False,
#                        random_state=None, splitter='best')

# %%
model.predict([[3,22.0,1,0,7.2500,1]])
# Out:
# array([0], dtype=int64)

# %%
model.predict([[3,0.0,0,0,7.2250,1]])
# Out:
# array([0], dtype=int64)

# %%
model.score(new,target)*100
# Out:
# 98.20426487093154

# %%
import matplotlib.pyplot as plt
plt.style.use('ggplot')
plt.scatter(new.Age,new.Fare,color="k",marker='*')
plt.xlabel("Age")
plt.ylabel("Fare")
# Out:
# Text(0, 0.5, 'Fare')
